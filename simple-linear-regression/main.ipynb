# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from linear_model import LinearRegression

# %% [markdown]
# ### Getting Data

# %%
df_train = pd.read_csv('data/train.csv')
df_train.dropna(inplace=True)
df_test = pd.read_csv('data/test.csv')
df_test.dropna(inplace=True)

# %% [markdown]
# ### Pre-processing

# %%
x_train = df_train.x.values.reshape(699,1)
y_train = df_train.y.values.reshape(699,1)
x_test = df_test.x.values.reshape(300,1)
y_test = df_test.y.values.reshape(300,1)

# %% [markdown]
# ### Training Model and Predict

# %%
mod = LinearRegression()
mod.fit(x_train, y_train)
# Out:
# Sucess

# %%
pred = mod.predict(x_test)

# %%
x_line = np.linspace(min(x_test), max(x_test))
y_line = mod.intercept_ + x_line * mod.coef_

# %% [markdown]
# ### Plotting Graphic of Linear Regression Result

# %%
sns.regplot(x=x_test, y=y_test,label='Datapoints')
plt.plot(x_line, y_line, color='red', label='Linear Regression', linewidth=3)
plt.xlabel('Input Data')
plt.ylabel('Output Data')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
print(f"Mean Squared Error {mean_squared_error(y_test, pred):.2f}")
print(f"Mean Absolute Error {mean_absolute_error(y_test, pred):.2f}")
print(f"r2_score {r2_score(y_test, pred):.2f}")
# Out:
# Mean Squared Error 9.43
# Mean Absolute Error 2.42
# r2_score 0.99
